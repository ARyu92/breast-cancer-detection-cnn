# %% [markdown]
# #This code snippet will preprocess the CBIS-DDSM dataset into dataset that will be ready for input into the model.
#
# #Pseudocode:
#
# 1. Read in the "all_data.csv" file which contains metadata of all images and put it in a pandas DF.
#     Each row has data on a patient image.
#     Patients can have a CC and MLO image per side.
#     Goal: create an object for 1 breast imaging study, left and right are kept separate.
# 2. Map the pathology column to a labels column, which will be 0 for benign or benign without callback, and 1 malignant
# 3. Group the meta data rows by same patient IDs and laterality.
# 4. For every grouping in groups:
#     Set variable patientID to the patient ID
#     Set variable laterality to the breast side
#     Set variable label to the mapped label.
#     Extract the path to the CC image.
#     Extract the path to the MLO image.
#
#     (to do- write a function that takes in a path to an image and returns the pixel data)
#     (to do- write a function that takes in raw pixel data and outputs a grayscaled, rescaled image)
#
#     Set variable CC_image to hold processed pixel data for Cranio-Caudal image.
#     Set variable MLO_image to hold processed pixel data for Mediolateral image.
#
#     Package CC and MLO image into a tensor. Should have a shape (400,400,2)
#
#     Generate a path to a tensor file and save it to tensor_file variable.
#     Save the tensor into the numpy file, .npy
#
#     Create a breast object that holds properties: patientID, laterality, label, tensor_file.
#
#     Append the breast object to a breast objects list.
#
#     End For Loop
#
#    Write the breast object to a JSON file.

# %%
import os
import pydicom
import numpy as np
import pandas as pd
import re
import cv2
import json
from pydicom.pixel_data_handlers.util import apply_voi_lut
from pydicom.pixel_data_handlers.util import apply_modality_lut, apply_voi_lut

# %%
data_directory = "../data/Data/manifest/CBIS-DDSM/"
metadata_file = "../data/Data/manifest/all_data.csv"

# %%
#1. Import the metadata
metadata = pd.read_csv(metadata_file)

# %%
metadata
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00038               2                 LEFT         CC
# 1       P_00038               2                 LEFT        MLO
# 2       P_00038               2                RIGHT         CC
# 3       P_00038               2                RIGHT         CC
# 4       P_00038               2                RIGHT        MLO
# ...         ...             ...                  ...        ...
# 3563    P_02033               2                RIGHT        MLO
# 3564    P_02079               2                RIGHT         CC
# 3565    P_02079               2                RIGHT        MLO
# 3566    P_02092               2                 LEFT         CC
# 3567    P_02092               2                 LEFT        MLO
#
#       abnormality id abnormality type             calc type calc distribution  \
# 0                  1    calcification  PUNCTATE-PLEOMORPHIC         CLUSTERED
# 1                  1    calcification  PUNCTATE-PLEOMORPHIC         CLUSTERED
# 2                  1    calcification              VASCULAR               NaN
# 3                  2    calcification              VASCULAR               NaN
# 4                  1    calcification              VASCULAR               NaN
# ...              ...              ...                   ...               ...
# 3563               1             mass             IRREGULAR       ILL_DEFINED
# 3564               1             mass                 ROUND        SPICULATED
# 3565               1             mass                 ROUND        SPICULATED
# 3566               1             mass             IRREGULAR        SPICULATED
# 3567               1             mass             IRREGULAR        SPICULATED
#
#       assessment                pathology  subtlety  \
# 0              4                   BENIGN         2
# 1              4                   BENIGN         2
# 2              2  BENIGN_WITHOUT_CALLBACK         5
# 3              2  BENIGN_WITHOUT_CALLBACK         5
# 4              2  BENIGN_WITHOUT_CALLBACK         5
# ...          ...                      ...       ...
# 3563           3                MALIGNANT         4
# 3564           3                MALIGNANT         5
# 3565           3                MALIGNANT         5
# 3566           3                MALIGNANT         2
# 3567           3                MALIGNANT         2
#
#                                         image file path  \
# 0     Calc-Test_P_00038_LEFT_CC/1.3.6.1.4.1.9590.100...
# 1     Calc-Test_P_00038_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 2     Calc-Test_P_00038_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 3     Calc-Test_P_00038_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 4     Calc-Test_P_00038_RIGHT_MLO/1.3.6.1.4.1.9590.1...
# ...                                                 ...
# 3563  Mass-Training_P_02033_RIGHT_MLO/1.3.6.1.4.1.95...
# 3564  Mass-Training_P_02079_RIGHT_CC/1.3.6.1.4.1.959...
# 3565  Mass-Training_P_02079_RIGHT_MLO/1.3.6.1.4.1.95...
# 3566  Mass-Training_P_02092_LEFT_CC/1.3.6.1.4.1.9590...
# 3567  Mass-Training_P_02092_LEFT_MLO/1.3.6.1.4.1.959...
#
#                                 cropped image file path  \
# 0     Calc-Test_P_00038_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1     Calc-Test_P_00038_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2     Calc-Test_P_00038_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 3     Calc-Test_P_00038_RIGHT_CC_2/1.3.6.1.4.1.9590....
# 4     Calc-Test_P_00038_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# ...                                                 ...
# 3563  Mass-Training_P_02033_RIGHT_MLO_1/1.3.6.1.4.1....
# 3564  Mass-Training_P_02079_RIGHT_CC_1/1.3.6.1.4.1.9...
# 3565  Mass-Training_P_02079_RIGHT_MLO_1/1.3.6.1.4.1....
# 3566  Mass-Training_P_02092_LEFT_CC_1/1.3.6.1.4.1.95...
# 3567  Mass-Training_P_02092_LEFT_MLO_1/1.3.6.1.4.1.9...
#
#                                      ROI mask file path
# 0     Calc-Test_P_00038_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1     Calc-Test_P_00038_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2     Calc-Test_P_00038_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 3     Calc-Test_P_00038_RIGHT_CC_2/1.3.6.1.4.1.9590....
# 4     Calc-Test_P_00038_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# ...                                                 ...
# 3563  Mass-Training_P_02033_RIGHT_MLO_1/1.3.6.1.4.1....
# 3564  Mass-Training_P_02079_RIGHT_CC_1/1.3.6.1.4.1.9...
# 3565  Mass-Training_P_02079_RIGHT_MLO_1/1.3.6.1.4.1....
# 3566  Mass-Training_P_02092_LEFT_CC_1/1.3.6.1.4.1.95...
# 3567  Mass-Training_P_02092_LEFT_MLO_1/1.3.6.1.4.1.9...
#
# [3568 rows x 14 columns]

# %%
#2. Map the pathology column to a labels column.
label_mapping = {
    "BENIGN" : 0,
    "BENIGN_WITHOUT_CALLBACK": 0, 
    "MALIGNANT" : 1
}

metadata["label"] = metadata["pathology"].map(label_mapping)

# %%
metadata["label"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3563    1
# 3564    1
# 3565    1
# 3566    1
# 3567    1
# Name: label, Length: 3568, dtype: int64

# %%
#Truncate image path for anything character that comes after "CC" or "MLO"
metadata["truncated_path"] = metadata["image file path"].str.extract(r"(.*(?:CC|MLO)/)")

# %%
metadata
# Out:
#      patient_id  breast density left or right breast image view  \
# 0       P_00038               2                 LEFT         CC
# 1       P_00038               2                 LEFT        MLO
# 2       P_00038               2                RIGHT         CC
# 3       P_00038               2                RIGHT         CC
# 4       P_00038               2                RIGHT        MLO
# ...         ...             ...                  ...        ...
# 3563    P_02033               2                RIGHT        MLO
# 3564    P_02079               2                RIGHT         CC
# 3565    P_02079               2                RIGHT        MLO
# 3566    P_02092               2                 LEFT         CC
# 3567    P_02092               2                 LEFT        MLO
#
#       abnormality id abnormality type             calc type calc distribution  \
# 0                  1    calcification  PUNCTATE-PLEOMORPHIC         CLUSTERED
# 1                  1    calcification  PUNCTATE-PLEOMORPHIC         CLUSTERED
# 2                  1    calcification              VASCULAR               NaN
# 3                  2    calcification              VASCULAR               NaN
# 4                  1    calcification              VASCULAR               NaN
# ...              ...              ...                   ...               ...
# 3563               1             mass             IRREGULAR       ILL_DEFINED
# 3564               1             mass                 ROUND        SPICULATED
# 3565               1             mass                 ROUND        SPICULATED
# 3566               1             mass             IRREGULAR        SPICULATED
# 3567               1             mass             IRREGULAR        SPICULATED
#
#       assessment                pathology  subtlety  \
# 0              4                   BENIGN         2
# 1              4                   BENIGN         2
# 2              2  BENIGN_WITHOUT_CALLBACK         5
# 3              2  BENIGN_WITHOUT_CALLBACK         5
# 4              2  BENIGN_WITHOUT_CALLBACK         5
# ...          ...                      ...       ...
# 3563           3                MALIGNANT         4
# 3564           3                MALIGNANT         5
# 3565           3                MALIGNANT         5
# 3566           3                MALIGNANT         2
# 3567           3                MALIGNANT         2
#
#                                         image file path  \
# 0     Calc-Test_P_00038_LEFT_CC/1.3.6.1.4.1.9590.100...
# 1     Calc-Test_P_00038_LEFT_MLO/1.3.6.1.4.1.9590.10...
# 2     Calc-Test_P_00038_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 3     Calc-Test_P_00038_RIGHT_CC/1.3.6.1.4.1.9590.10...
# 4     Calc-Test_P_00038_RIGHT_MLO/1.3.6.1.4.1.9590.1...
# ...                                                 ...
# 3563  Mass-Training_P_02033_RIGHT_MLO/1.3.6.1.4.1.95...
# 3564  Mass-Training_P_02079_RIGHT_CC/1.3.6.1.4.1.959...
# 3565  Mass-Training_P_02079_RIGHT_MLO/1.3.6.1.4.1.95...
# 3566  Mass-Training_P_02092_LEFT_CC/1.3.6.1.4.1.9590...
# 3567  Mass-Training_P_02092_LEFT_MLO/1.3.6.1.4.1.959...
#
#                                 cropped image file path  \
# 0     Calc-Test_P_00038_LEFT_CC_1/1.3.6.1.4.1.9590.1...
# 1     Calc-Test_P_00038_LEFT_MLO_1/1.3.6.1.4.1.9590....
# 2     Calc-Test_P_00038_RIGHT_CC_1/1.3.6.1.4.1.9590....
# 3     Calc-Test_P_00038_RIGHT_CC_2/1.3.6.1.4.1.9590....
# 4     Calc-Test_P_00038_RIGHT_MLO_1/1.3.6.1.4.1.9590...
# ...                                                 ...
# 3563  Mass-Training_P_02033_RIGHT_MLO_1/1.3.6.1.4.1....
# 3564  Mass-Training_P_02079_RIGHT_CC_1/1.3.6.1.4.1.9...
# 3565  Mass-Training_P_02079_RIGHT_MLO_1/1.3.6.1.4.1....
# 3566  Mass-Training_P_02092_LEFT_CC_1/1.3.6.1.4.1.95...
# 3567  Mass-Training_P_02092_LEFT_MLO_1/1.3.6.1.4.1.9...
#
#                                      ROI mask file path  label  \
# 0     Calc-Test_P_00038_LEFT_CC_1/1.3.6.1.4.1.9590.1...      0
# 1     Calc-Test_P_00038_LEFT_MLO_1/1.3.6.1.4.1.9590....      0
# 2     Calc-Test_P_00038_RIGHT_CC_1/1.3.6.1.4.1.9590....      0
# 3     Calc-Test_P_00038_RIGHT_CC_2/1.3.6.1.4.1.9590....      0
# 4     Calc-Test_P_00038_RIGHT_MLO_1/1.3.6.1.4.1.9590...      0
# ...                                                 ...    ...
# 3563  Mass-Training_P_02033_RIGHT_MLO_1/1.3.6.1.4.1....      1
# 3564  Mass-Training_P_02079_RIGHT_CC_1/1.3.6.1.4.1.9...      1
# 3565  Mass-Training_P_02079_RIGHT_MLO_1/1.3.6.1.4.1....      1
# 3566  Mass-Training_P_02092_LEFT_CC_1/1.3.6.1.4.1.95...      1
# 3567  Mass-Training_P_02092_LEFT_MLO_1/1.3.6.1.4.1.9...      1
#
#                         truncated_path
# 0           Calc-Test_P_00038_LEFT_CC/
# 1          Calc-Test_P_00038_LEFT_MLO/
# 2          Calc-Test_P_00038_RIGHT_CC/
# 3          Calc-Test_P_00038_RIGHT_CC/
# 4         Calc-Test_P_00038_RIGHT_MLO/
# ...                                ...
# 3563  Mass-Training_P_02033_RIGHT_MLO/
# 3564   Mass-Training_P_02079_RIGHT_CC/
# 3565  Mass-Training_P_02079_RIGHT_MLO/
# 3566    Mass-Training_P_02092_LEFT_CC/
# 3567   Mass-Training_P_02092_LEFT_MLO/
#
# [3568 rows x 16 columns]

# %%
#3. Group the metadata by same patient IDs and laterality
grouped = metadata.groupby(["patient_id", "left or right breast"])

# %%
grouped.groups.keys()
# Out:
# dict_keys([('P_00001', 'LEFT'), ('P_00004', 'LEFT'), ('P_00004', 'RIGHT'), ('P_00005', 'RIGHT'), ('P_00007', 'LEFT'), ('P_00008', 'LEFT'), ('P_00008', 'RIGHT'), ('P_00009', 'RIGHT'), ('P_00010', 'LEFT'), ('P_00011', 'LEFT'), ('P_00012', 'LEFT'), ('P_00013', 'RIGHT'), ('P_00014', 'LEFT'), ('P_00015', 'LEFT'), ('P_00016', 'LEFT'), ('P_00017', 'LEFT'), ('P_00018', 'RIGHT'), ('P_00019', 'RIGHT'), ('P_00020', 'LEFT'), ('P_00021', 'LEFT'), ('P_00021', 'RIGHT'), ('P_00022', 'LEFT'), ('P_00023', 'RIGHT'), ('P_00024', 'LEFT'), ('P_00026', 'LEFT'), ('P_00027', 'RIGHT'), ('P_00028', 'LEFT'), ('P_00029', 'LEFT'), ('P_00030', 'LEFT'), ('P_00030', 'RIGHT'), ('P_00031', 'LEFT'), ('P_00032', 'RIGHT'), ('P_00034', 'RIGHT'), ('P_00037', 'RIGHT'), ('P_00038', 'LEFT'), ('P_00038', 'RIGHT'), ('P_00039', 'RIGHT'), ('P_00041', 'LEFT'), ('P_00043', 'LEFT'), ('P_00044', 'RIGHT'), ('P_00045', 'LEFT'), ('P_00046', 'RIGHT'), ('P_00047', 'LEFT'), ('P_00048', 'RIGHT'), ('P_00049', 'RIGHT'), ('P_00051', 'LEFT'), ('P_00054', 'RIGHT'), ('P_00055', 'LEFT'), ('P_00056', 'LEFT'), ('P_00057', 'RIGHT'), ('P_00058', 'RIGHT'), ('P_00059', 'LEFT'), ('P_00060', 'RIGHT'), ('P_00061', 'RIGHT'), ('P_00062', 'LEFT'), ('P_00063', 'RIGHT'), ('P_00064', 'RIGHT'), ('P_00065', 'LEFT'), ('P_00066', 'LEFT'), ('P_00068', 'RIGHT'), ('P_00071', 'RIGHT'), ('P_00074', 'LEFT'), ('P_00074', 'RIGHT'), ('P_00076', 'LEFT'), ('P_00077', 'LEFT'), ('P_00077', 'RIGHT'), ('P_00078', 'LEFT'), ('P_00079', 'RIGHT'), ('P_00080', 'RIGHT'), ('P_00081', 'RIGHT'), ('P_00083', 'RIGHT'), ('P_00084', 'LEFT'), ('P_00085', 'RIGHT'), ('P_00086', 'RIGHT'), ('P_00088', 'LEFT'), ('P_00090', 'LEFT'), ('P_00091', 'LEFT'), ('P_00092', 'LEFT'), ('P_00092', 'RIGHT'), ('P_00094', 'RIGHT'), ('P_00095', 'LEFT'), ('P_00096', 'RIGHT'), ('P_00098', 'LEFT'), ('P_00098', 'RIGHT'), ('P_00099', 'LEFT'), ('P_00100', 'RIGHT'), ('P_00101', 'RIGHT'), ('P_00105', 'LEFT'), ('P_00106', 'LEFT'), ('P_00106', 'RIGHT'), ('P_00107', 'RIGHT'), ('P_00108', 'LEFT'), ('P_00109', 'LEFT'), ('P_00110', 'LEFT'), ('P_00110', 'RIGHT'), ('P_00112', 'LEFT'), ('P_00112', 'RIGHT'), ('P_00114', 'LEFT'), ('P_00116', 'RIGHT'), ('P_00117', 'LEFT'), ('P_00118', 'RIGHT'), ('P_00119', 'LEFT'), ('P_00120', 'LEFT'), ('P_00121', 'LEFT'), ('P_00122', 'RIGHT'), ('P_00123', 'LEFT'), ('P_00124', 'RIGHT'), ('P_00126', 'RIGHT'), ('P_00127', 'RIGHT'), ('P_00128', 'LEFT'), ('P_00129', 'LEFT'), ('P_00131', 'LEFT'), ('P_00132', 'LEFT'), ('P_00133', 'LEFT'), ('P_00134', 'LEFT'), ('P_00136', 'LEFT'), ('P_00137', 'LEFT'), ('P_00140', 'LEFT'), ('P_00140', 'RIGHT'), ('P_00141', 'LEFT'), ('P_00145', 'LEFT'), ('P_00146', 'RIGHT'), ('P_00147', 'RIGHT'), ('P_00148', 'RIGHT'), ('P_00149', 'LEFT'), ('P_00150', 'RIGHT'), ('P_00151', 'RIGHT'), ('P_00156', 'RIGHT'), ('P_00157', 'LEFT'), ('P_00158', 'RIGHT'), ('P_00159', 'LEFT'), ('P_00159', 'RIGHT'), ('P_00160', 'LEFT'), ('P_00160', 'RIGHT'), ('P_00161', 'LEFT'), ('P_00162', 'LEFT'), ('P_00163', 'LEFT'), ('P_00164', 'RIGHT'), ('P_00166', 'RIGHT'), ('P_00169', 'RIGHT'), ('P_00171', 'RIGHT'), ('P_00172', 'LEFT'), ('P_00173', 'LEFT'), ('P_00173', 'RIGHT'), ('P_00174', 'RIGHT'), ('P_00175', 'RIGHT'), ('P_00177', 'LEFT'), ('P_00179', 'LEFT'), ('P_00180', 'LEFT'), ('P_00181', 'RIGHT'), ('P_00182', 'LEFT'), ('P_00183', 'RIGHT'), ('P_00185', 'LEFT'), ('P_00187', 'LEFT'), ('P_00188', 'RIGHT'), ('P_00189', 'LEFT'), ('P_00190', 'LEFT'), ('P_00192', 'RIGHT'), ('P_00194', 'RIGHT'), ('P_00195', 'LEFT'), ('P_00196', 'RIGHT'), ('P_00197', 'RIGHT'), ('P_00198', 'LEFT'), ('P_00199', 'LEFT'), ('P_00200', 'LEFT'), ('P_00200', 'RIGHT'), ('P_00201', 'LEFT'), ('P_00202', 'RIGHT'), ('P_00203', 'LEFT'), ('P_00205', 'RIGHT'), ('P_00206', 'RIGHT'), ('P_00207', 'LEFT'), ('P_00208', 'RIGHT'), ('P_00209', 'LEFT'), ('P_00212', 'RIGHT'), ('P_00214', 'LEFT'), ('P_00214', 'RIGHT'), ('P_00215', 'RIGHT'), ('P_00217', 'LEFT'), ('P_00218', 'LEFT'), ('P_00219', 'RIGHT'), ('P_00220', 'LEFT'), ('P_00221', 'RIGHT'), ('P_00223', 'LEFT'), ('P_00224', 'LEFT'), ('P_00224', 'RIGH ...

# %%
#This function finds the dicom file that may exist in a directory.
def get_dicom_path(directory_path):
    dicom_paths = []
    directory_path = "../data/Data/manifest/CBIS-DDSM/" + directory_path
    for dirpath, _, filenames in os.walk(directory_path):
        for filename in filenames:
            if filename.lower().endswith(".dcm"):
                full_path = os.path.join(dirpath, filename)
                full_path = full_path
                dicom_paths.append(full_path)
    return dicom_paths

# %%
dicom_path = get_dicom_path(metadata.iloc[0]["truncated_path"])

# %%
metadata.iloc[1]["truncated_path"]
# Out:
# 'Calc-Test_P_00038_RIGHT_MLO/'

# %%
def min_max_normalize(values):
    min_val = np.min(values)
    max_val = np.max(values)
    return (values - min_val) / (max_val - min_val)

# %%
#This function takes in a file path and returns the raw DICOM pixel data 
def get_pixel_data(path):
    dicom_file = pydicom.dcmread(path)
    pixels = dicom_file.pixel_array
    pixels = apply_voi_lut(pixels, dicom_file)
    pixels = cv2.resize(pixels, (512,512))
    #pixels = min_max_normalize(pixels)
    return pixels


pixel_data = get_pixel_data(dicom_path[0])

# %%
print(pixel_data.shape)
# Out:
# (512, 512)

# %% [markdown]
# breast_objects = []
# for (patient_id, laterality), group in grouped:
#     views = group.set_index("image view")
#
#     try:
#         cc_path = views.loc["CC", "truncated_path"]
#         if isinstance(cc_path, pd.Series):
#             cc_path = cc_path.iloc[0]  # pick first
#
#         mlo_path = views.loc["MLO", "truncated_path"]
#         if isinstance(mlo_path, pd.Series):
#             mlo_path = mlo_path.iloc[0]  # pick first
#
#         label = int(views.iloc[0]["label"])
#
#         breast_object = {
#             "patient_id": patient_id,
#             "laterality": laterality,
#             "cc_path": cc_path,
#             "mlo_path": mlo_path,
#             "label": label
#         }
#
#         cc_image = get_pixel_data(get_dicom_path(cc_path)[0])
#         mlo_image = get_pixel_data(get_dicom_path(mlo_path)[0])
#
#         np.save(f"../data/Processed Data/{patient_id}_{laterality}.npy", [cc_image, mlo_image])
#         breast_objects.append(breast_object)
#
#     except Exception as e:
#         continue
#
# with open("../data/meta_data.json", "w") as f:
#     json.dump(breast_objects, f)

# %%
import os
import json

# Create output dirs
train_dir = "../data/Processed Data/train"
test_dir = "../data/Processed Data/test"
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

train_objects = []
test_objects = []

for (patient_id, laterality), group in grouped:
    views = group.set_index("image view")

    try:
        cc_path = views.loc["CC", "truncated_path"]
        if isinstance(cc_path, pd.Series):
            cc_path = cc_path.iloc[0]

        mlo_path = views.loc["MLO", "truncated_path"]
        if isinstance(mlo_path, pd.Series):
            mlo_path = mlo_path.iloc[0]

        label = int(views.iloc[0]["label"])

        # Decide split dir
        if "test" in cc_path.lower() or "test" in mlo_path.lower():
            split_dir = "test"
            save_dir = test_dir
            meta_list = test_objects
        elif "train" in cc_path.lower() or "train" in mlo_path.lower():
            split_dir = "train"
            save_dir = train_dir
            meta_list = train_objects
        else:
            # default fallback to train
            split_dir = "train"
            save_dir = train_dir
            meta_list = train_objects

        # Load images
        cc_image = get_pixel_data(get_dicom_path(cc_path)[0])
        mlo_image = get_pixel_data(get_dicom_path(mlo_path)[0])

        # Save processed .npy file
        save_path = os.path.join(save_dir, f"{patient_id}_{laterality}.npy")
        np.save(save_path, [cc_image, mlo_image])

        # Add to the appropriate metadata list
        breast_object = {
            "patient_id": patient_id,
            "laterality": laterality,
            "processed_path": save_path,
            "label": label,
            "split": split_dir
        }
        meta_list.append(breast_object)

    except Exception:
        continue

# Save separate metadata files
with open("../data/meta_train.json", "w") as f:
    json.dump(train_objects, f)

with open("../data/meta_test.json", "w") as f:
    json.dump(test_objects, f)

print(f"Saved {len(train_objects)} train entries and {len(test_objects)} test entries.")
# Out:
# Saved 1054 train entries and 270 test entries.
